# %% [markdown]
# Run the following cell to download the branch on the local filesystem and install it as a package

# %%
# !git clone -b audioMNIST https://github.com/DomMcOyle/speechbrain-warmup.git
# %cd /content/speechbrain-warmup/
# !pip install -e .
# %cd ../
# Out:
# Cloning into 'speechbrain-warmup'...
# remote: Enumerating objects: 64062, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 64062 (delta 49), reused 67 (delta 44), pack-reused 63984
# Receiving objects: 100% (64062/64062), 81.52 MiB | 21.45 MiB/s, done.
# Resolving deltas: 100% (42466/42466), done.
# /content/speechbrain-warmup
# Obtaining file:///content/speechbrain-warmup
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 11.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# Run the following cell to change the current working directory and test the recipe for the audioMNIST (FSDD) classification task.

# %%
# %cd speechbrain-warmup/recipes/audioMNIST/
# !python train.py hparams.yaml
# Out:
# /content/speechbrain-warmup/recipes/audioMNIST
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: ./results/digit_class/42
# ...
# master.zip: 16.4MB [00:01, 11.3MB/s]
# Extracting ./data/audioMNIST.zip to ./data
# prepare_audioMNIST - Creating train.json, valid.json, and test.json
# prepare_audioMNIST - train.json successfully created!
# prepare_audioMNIST - valid.json successfully created!
# prepare_audioMNIST - test.json successfully created!
# speechbrain.dataio.encoder - Load called, but CategoricalEncoder is not empty. Loaded data will overwrite everything. This is normal if there is e.g. an unk label defined at init.
# speechbrain.core - Info: ckpt_interval_minutes arg from hparam file is used
# speechbrain.core - 141.1k trainable parameters in DigitClassBrain
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# speechbrain.utils.epoch_loop - Going into epoch 1
# ...

# %% [markdown]
# Run the following cell to get rid of previous run's checkpoints

# %%
# !rm -r results/digit_class/42
